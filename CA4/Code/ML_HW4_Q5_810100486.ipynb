# %% [markdown]
# # **SVM Kernels**
# The SVM algorithm is implemented in practice using a kernel. A kernel transforms an input data space into the required form. SVM uses a technique called the kernel trick. Here, the kernel takes a low-dimensional input space and transforms it into a higher dimensional space. In other words, you can say that it converts nonseparable problem to separable problems by adding more dimension to it. It is most useful in non-linear separation problem. Kernel trick helps you to build a more accurate classifier.
#
# - **Linear Kernel** A linear kernel can be used as normal dot product any two given observations. The product between two vectors is the sum of the multiplication of each pair of input values.
#
# $$ K(x, xi) = sum(x * xi) $$
#
# - **Polynomial Kernel** A polynomial kernel is a more generalized form of the linear kernel. The polynomial kernel can distinguish curved or nonlinear input space
#
# $$ K(x,xi) = 1 + sum(x * xi)^d $$
# Where d is the degree of the polynomial. d=1 is similar to the linear transformation. The degree needs to be manually specified in the learning algorithm.
#
# - **Radial Basis Function Kernel** The Radial basis function kernel is a popular kernel function commonly used in support vector machine classification. RBF can map an input space in infinite dimensional space.
#
# $$ K(x,xi) = exp(-gamma * sum((x – xi^2)) $$
# Here gamma is a parameter, which ranges from 0 to 1. A higher value of gamma will perfectly fit the training dataset, which causes over-fitting. Gamma=0.1 is considered to be a good default value. The value of gamma needs to be manually specified in the learning algorithm.

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("q5.csv")
df
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# 17895                                      59.935939
# 17896                                      53.902400
# 17897                                      85.797340
#
#         Excess kurtosis of the integrated profile  \
# 0                                       -0.234571
# 1                                        0.465318
# 2                                        0.323328
# 3                                       -0.068415
# 4                                        0.600866
# ...                                           ...
# 17893                                   -0.187846
# 17894                                    0.127978
# 17895                                    0.159363
# 17896                                    0.201161
# 17897                                    1.406391
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                                -0.699648                   3.199833
# 1                                -0.515088                   1.677258
# 2                                 1.051164                   3.121237
# 3                                -0.636238                   3.642977
# 4                                 1.123492                   1.178930
# ...                                    ...                        ...
# 17893                            -0.738123                   1.296823
# 17894                             0.323061                  16.409699
# 17895                            -0.743025                  21.430602
# 17896                            -0.024789                   1.946488
# 17897                             0.089520                 188.306020
#
#         Standard deviation of the DM-SNR curve  \
# 0                                    19.110426
# 1                                    14.860146
# 2                                    21.744669
# 3                                    20.959280
# 4                                    11.468720
# ...                                        ...
# 17893                                12.166062
# 17894                                44.626893
# 17895                                58.872000
# 17896                                13.381731
# 17897                                64.712562
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                                  7.975532                      74.242225
# 1                                 10.576487                     127.393580
# 2                                  7.735822                      63.171909
# 3                                  6.896499                      53.593661
# 4                                 14.269573                     252.567306
# ...                                     ...                            ...
# 17893                             15.450260                     285.931022
# 17894                              2.945244                       8.297092
# 17895                              2.499517                       4.595173
# 17896                             10.007967                     134.238910
# 17897                             -1.597527                       1.429475
#
#        target_class
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 17893             0
# 17894             0
# 17895             0
# 17896             0
# 17897             0
#
# [17898 rows x 9 columns]

# %%
X = df.loc[:, df.columns != 'target_class']
X
# Out:
#         Mean of the integrated profile  \
# 0                           140.562500
# 1                           102.507812
# 2                           103.015625
# 3                           136.750000
# 4                            88.726562
# ...                                ...
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 0                                          55.683782
# 1                                          58.882430
# 2                                          39.341649
# 3                                          57.178449
# 4                                          40.672225
# ...                                              ...
# 17893                                      59.847421
# 17894                                      49.485605
# 17895                                      59.935939
# 17896                                      53.902400
# 17897                                      85.797340
#
#         Excess kurtosis of the integrated profile  \
# 0                                       -0.234571
# 1                                        0.465318
# 2                                        0.323328
# 3                                       -0.068415
# 4                                        0.600866
# ...                                           ...
# 17893                                   -0.187846
# 17894                                    0.127978
# 17895                                    0.159363
# 17896                                    0.201161
# 17897                                    1.406391
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                                -0.699648                   3.199833
# 1                                -0.515088                   1.677258
# 2                                 1.051164                   3.121237
# 3                                -0.636238                   3.642977
# 4                                 1.123492                   1.178930
# ...                                    ...                        ...
# 17893                            -0.738123                   1.296823
# 17894                             0.323061                  16.409699
# 17895                            -0.743025                  21.430602
# 17896                            -0.024789                   1.946488
# 17897                             0.089520                 188.306020
#
#         Standard deviation of the DM-SNR curve  \
# 0                                    19.110426
# 1                                    14.860146
# 2                                    21.744669
# 3                                    20.959280
# 4                                    11.468720
# ...                                        ...
# 17893                                12.166062
# 17894                                44.626893
# 17895                                58.872000
# 17896                                13.381731
# 17897                                64.712562
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 0                                  7.975532                      74.242225
# 1                                 10.576487                     127.393580
# 2                                  7.735822                      63.171909
# 3                                  6.896499                      53.593661
# 4                                 14.269573                     252.567306
# ...                                     ...                            ...
# 17893                             15.450260                     285.931022
# 17894                              2.945244                       8.297092
# 17895                              2.499517                       4.595173
# 17896                             10.007967                     134.238910
# 17897                             -1.597527                       1.429475
#
# [17898 rows x 8 columns]

# %%
y = df["target_class"]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17893    0
# 17894    0
# 17895    0
# 17896    0
# 17897    0
# Name: target_class, Length: 17898, dtype: int64

# %% [markdown]
# ### b)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (11991, 8)

# %%
X_test.shape
# Out:
# (5907, 8)

# %%
tests = {
    "rbf": [1, 100, 1000],
    "linear":[1, 100, 1000],
    "poly": [1, 100],
    "sigmoid": [1, 100],
}

# %%
df = pd.DataFrame(columns=['kernel', 'C', 'accuracy'])
i = 0
for kernel in tqdm(tests):
  for c in tqdm(tests[kernel]):
    clf = SVC(kernel=kernel, C=c)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    df.loc[i] = [kernel, c, acc]
    i = i + 1
df
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#     kernel     C  accuracy
# 0      rbf     1  0.972575
# 1      rbf   100  0.977992
# 2      rbf  1000  0.978500
# 3   linear     1  0.978669
# 4   linear   100  0.978331
# 5   linear  1000  0.977992
# 6     poly     1  0.972236
# 7     poly   100  0.976299
# 8  sigmoid     1  0.925681
# 9  sigmoid   100  0.921788

# %% [markdown]
# ### c)

# %%
params = [
  {'C': [1, 10, 100, 500], 'gamma':[0.1, 0.3, 0.5, 0.7, 0.9], 'kernel': ['rbf']},
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'degree':[2,3,4], 'gamma':[0.01, 0.03, 0.05], 'kernel':['poly'], 'max_iter':[10000]}
]

# %%
# Ran it once and noticed cross-validation doesn't matter that much so it is set to 2
clf = GridSearchCV(estimator=SVC(), param_grid=params, cv=2, verbose = 5, scoring='accuracy') 
# %time clf.fit(X_train, y_train)
clf.cv_results_
# Out:
# Fitting 2 folds for each of 33 candidates, totalling 66 fits
# [CV 1/2] END ........C=1, gamma=0.1, kernel=rbf;, score=0.908 total time=   8.3s
# [CV 2/2] END ........C=1, gamma=0.1, kernel=rbf;, score=0.908 total time=   7.9s
# [CV 1/2] END ........C=1, gamma=0.3, kernel=rbf;, score=0.907 total time=   8.6s
# [CV 2/2] END ........C=1, gamma=0.3, kernel=rbf;, score=0.907 total time=   8.7s
# [CV 1/2] END ........C=1, gamma=0.5, kernel=rbf;, score=0.907 total time=   8.9s
# [CV 2/2] END ........C=1, gamma=0.5, kernel=rbf;, score=0.907 total time=   8.9s
# [CV 1/2] END ........C=1, gamma=0.7, kernel=rbf;, score=0.907 total time=   8.9s
# [CV 2/2] END ........C=1, gamma=0.7, kernel=rbf;, score=0.907 total time=   9.0s
# [CV 1/2] END ........C=1, gamma=0.9, kernel=rbf;, score=0.907 total time=   9.1s
# [CV 2/2] END ........C=1, gamma=0.9, kernel=rbf;, score=0.907 total time=   9.0s
# [CV 1/2] END .......C=10, gamma=0.1, kernel=rbf;, score=0.908 total time=   8.0s
# [CV 2/2] END .......C=10, gamma=0.1, kernel=rbf;, score=0.907 total time=   8.2s
# [CV 1/2] END .......C=10, gamma=0.3, kernel=rbf;, score=0.907 total time=   9.5s
# [CV 2/2] END .......C=10, gamma=0.3, kernel=rbf;, score=0.906 total time=   8.8s
# [CV 1/2] END .......C=10, gamma=0.5, kernel=rbf;, score=0.907 total time=   9.1s
# [CV 2/2] END .......C=10, gamma=0.5, kernel=rbf;, score=0.907 total time=   9.0s
# [CV 1/2] END .......C=10, gamma=0.7, kernel=rbf;, score=0.907 total time=   9.2s
# [CV 2/2] END .......C=10, gamma=0.7, kernel=rbf;, score=0.907 total time=   9.0s
# [CV 1/2] END .......C=10, gamma=0.9, kernel=rbf;, score=0.907 total time=   9.3s
# [CV 2/2] END .......C=10, gamma=0.9, kernel=rbf;, score=0.907 total time=   9.1s
# [CV 1/2] END ......C=100, gamma=0.1, kernel=rbf;, score=0.908 total time=   8.1s
# [CV 2/2] END ......C=100, gamma=0.1, kernel=rbf;, score=0.907 total time=   8.0s
# [CV 1/2] END ......C=100, gamma=0.3, kernel=rbf;, score=0.907 total time=   8.8s
# [CV 2/2] END ......C=100, gamma=0.3, kernel=rbf;, score=0.906 total time=   9.4s
# [CV 1/2] END ......C=100, gamma=0.5, kernel=rbf;, score=0.907 total time=   9.3s
# [CV 2/2] END ......C=100, gamma=0.5, kernel=rbf;, score=0.907 total time=   9.8s
# [CV 1/2] END ......C=100, gamma=0.7, kernel=rbf;, score=0.907 total time=   9.7s
# [CV 2/2] END ......C=100, gamma=0.7, kernel=rbf;, score=0.907 total time=  10.9s
# [CV 1/2] END ......C=100, gamma=0.9, kernel=rbf;, score=0.907 total time=  11.6s
# [CV 2/2] END ......C=100, gamma=0.9, kernel=rbf;, score=0.907 total time=  10.4s
# [CV 1/2] END ......C=500, gamma=0.1, kernel=rbf;, score=0.908 total time=   9.8s
# [CV 2/2] END ......C=500, gamma=0.1, kernel=rbf;, score=0.907 total time=  10.2s
# [CV 1/2] END ......C=500, gamma=0.3, kernel=rbf;, score=0.907 total time=  10.5s
# [CV 2/2] END ......C=500, gamma=0.3, kernel=rbf;, score=0.906 total time=  10.0s
# [CV 1/2] END ......C=500, gamma=0.5, kernel=rbf;, score=0.907 total time=  11.1s
# [CV 2/2] END ......C=500, gamma=0.5, kernel=rbf;, score=0.907 total time=  10.5s
# [CV 1/2] END ......C=500, gamma=0.7, kernel=rbf;, score=0.907 total time=  10.9s
# [CV 2/2] END ......C=500, gamma=0.7, kernel=rbf;, score=0.907 total time=  10.3s
# [CV 1/2] END ......C=500, gamma=0.9, kernel=rbf;, score=0.907 total time=   9.1s
# [CV 2/2] END ......C=500, gamma=0.9, kernel=rbf;, score=0.907 total time=  10.4s
# [CV 1/2] END ................C=1, kernel=linear;, score=0.979 total time=   4.8s
# [CV 2/2] END ................C=1, kernel=linear;, score=0.980 total time=   7.5s
# [CV 1/2] END ...............C=10, kernel=linear;, score=0.980 total time=  28.9s
# [CV 2/2] END ...............C=10, kernel=linear;, score=0.980 total time=  53.5s
# [CV 1/2] END ..............C=100, kernel=linear;, score=0.979 total time= 2.3min
# [CV 2/2] END ..............C=100, kernel=linear;, score=0.979 total time= 2.3min
# [CV 1/2] END .............C=1000, kernel=linear;, score=0.979 total time= 3.5min
# [CV 2/2] END .............C=1000, kernel=linear;, score=0.978 total time= 4.8min
# [CV 1/2] END degree=2, gamma=0.01, kernel=poly, max_iter=1000;, score=0.429 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 2/2] END degree=2, gamma=0.01, kernel=poly, max_iter=1000;, score=0.181 total time=   0.0s
# [CV 1/2] END degree=2, gamma=0.03, kernel=poly, max_iter=1000;, score=0.490 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 2/2] END degree=2, gamma=0.03, kernel=poly, max_iter=1000;, score=0.220 total time=   0.0s
# [CV 1/2] END degree=2, gamma=0.05, kernel=poly, max_iter=1000;, score=0.170 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 2/2] END degree=2, gamma=0.05, kernel=poly, max_iter=1000;, score=0.321 total time=   0.0s
# [CV 1/2] END degree=3, gamma=0.01, kernel=poly, max_iter=1000;, score=0.372 total time=   0.0s
# [CV 2/2] END degree=3, gamma=0.01, kernel=poly, max_iter=1000;, score=0.722 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 1/2] END degree=3, gamma=0.03, kernel=poly, max_iter=1000;, score=0.165 total time=   0.0s
# [CV 2/2] END degree=3, gamma=0.03, kernel=poly, max_iter=1000;, score=0.157 total time=   0.0s
# [CV 1/2] END degree=3, gamma=0.05, kernel=poly, max_iter=1000;, score=0.154 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 2/2] END degree=3, gamma=0.05, kernel=poly, max_iter=1000;, score=0.258 total time=   0.0s
# [CV 1/2] END degree=4, gamma=0.01, kernel=poly, max_iter=1000;, score=0.182 total time=   0.0s
# [CV 2/2] END degree=4, gamma=0.01, kernel=poly, max_iter=1000;, score=0.895 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 1/2] END degree=4, gamma=0.03, kernel=poly, max_iter=1000;, score=0.166 total time=   0.0s
# [CV 2/2] END degree=4, gamma=0.03, kernel=poly, max_iter=1000;, score=0.169 total time=   0.0s
# [CV 1/2] END degree=4, gamma=0.05, kernel=poly, max_iter=1000;, score=0.116 total time=   0.0s
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# C:\Users\mamat\anaconda3\lib\site-packages\sklearn\svm\_base.py:255: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# [CV 2/2] END degree=4, gamma=0.05, kernel=poly, max_iter=1000;, score=0.895 total time=   0.0s
# Wall time: 22min 45s
# {'mean_fit_time': array([3.40395987e+00, 3.30347121e+00, 3.41013670e+00, 3.46202064e+00,
#         3.41897035e+00, 3.50600433e+00, 3.36752403e+00, 3.57396376e+00,
#         3.60250533e+00, 3.67949820e+00, 3.52602315e+00, 3.68094587e+00,
#         3.64252234e+00, 4.05904627e+00, 4.58667302e+00, 4.36824787e+00,
#         4.13304758e+00, 4.58588278e+00, 4.46968627e+00, 3.85540378e+00,
#         6.18312573e+00, 4.12070742e+01, 1.39522470e+02, 2.49472267e+02,
#         6.89646006e-02, 7.04970360e-02, 7.15180635e-02, 6.55297041e-02,
#         6.44949675e-02, 6.25166893e-02, 5.74972630e-02, 5.79980612e-02,
#         6.00305796e-02]),
#  'std_fit_time': array([7.89946318e-02, 6.53183460e-03, 5.18417358e-03, 1.01470947e-03,
#         9.29706097e-02, 4.20000553e-02, 1.44802332e-02, 1.01053715e-03,
#         3.05033922e-02, 5.94999790e-02, 2.49757767e-02, 1.77989006e-01,
#         4.75192070e-02, 7.09087849e-02, 3.47787142e-01, 3.29125762e-01,
#         1.71364069e-01, 3.79650712e-01, 1.17917538e-01, 2.09363103e-01,
#         1.31430888e+00, 1.22853522e+01, 2.82265663e-01, 4.08991809e+01,
#         1.03366375e-03, 2.49671936e-03, 2.47824192e-03, 3.48842144e-03,
#         4.98175621e-04, 5.51962852e-03, 5.01871109e-04, 4.00078297e-03,
#         2.96437740e-03]),
#  'mean_score_time': array([4.78605008, 5.4581058 , 5.57704639, 5.55349553, 5.69902253,
#         4.70378339, 5.85699654, 5.56903279, 5.59147549, 5.62000382,
#         4.62247443, 5.51801765, 6.04364979, 6.33825052, 6.48458314,
#         5.72184443, 6.23659861, 6.34513581, 6.21389973, 6.01054204,
#         0.06200302, 0.05947793, 0.05050123, 0.03951728, 0.03600192,
#         0.03799963, 0.0424906 , 0.03147197, 0.03150439, 0.03548312,
#         0.02900004, 0.02750003, 0.02696574]),
#  'std_score_time': array([1.20988846e-01, 2.70564556e-02, 1.69968605e-02, 4.24557924e-02,
#         5.59802055e-02, 1.39790177e-01, 3.76998186e-01, 1.10150576e-02,
#         4.34784889e-02, 8.99922848e-03, 2.84790993e-02, 1.59980893e-01,
#         3.05143714e-01, 5.44256330e-01, 2.48619318e-01, 1.23399973e-01,
#         3.97854686e-01, 6.90575957e-01, 4.37562346e-01, 4.10584569e-01,
#         4.01055813e-03, 4.85062599e-04, 9.50276852e-03, 2.51495838e-03,
#         4.00161743e-03, 1.00040436e-03, 1.52766705e-03, 5.13792038e-04,
#         1.49846077e-03, 3.47924232e-03, 9.98020172e-04, 2.50184536e-03,
#         3.03542614e-03]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 1, 10, 10, 10, 10, 10, 100, 100, 100, 100,
#                     100, 500, 500, 500, 500, 500, 1, 10, 100, 1000, --, --,
#                     --, --, --, --, --, --, --],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                      True],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=[0.1, 0.3, 0.5, 0.7, 0.9, 0.1, 0.3, 0.5, 0.7, 0.9, 0.1,
#                     0.3, 0.5, 0.7, 0.9, 0.1, 0.3, 0.5, 0.7, 0.9, --, --,
#                     --, --, 0.01, 0.03, 0.05, 0.01, 0.03, 0.05, 0.01, 0.03,
#                     0.05],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False,  True,  True,  True,  True,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf',
#                     'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf', 'rbf',
#                     'rbf', 'rbf', 'rbf', 'rbf', 'linear', 'linear',
#                     'linear', 'linear', 'poly', 'poly', 'poly', 'poly',
#                     'poly', 'poly', 'poly', 'poly', 'poly'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_degree': masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                     --, --, --, --, --, --, --, --, --, --, 2, 2, 2, 3, 3,
#                     3, 4, 4, 4],
#               mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[--, --, --, --, --, --, --, --, --, --, --, --, --, --,
#                     --, --, --, --, --, --, --, --, --, --, 1000, 1000,
#                     1000, 1000, 1000, 1000, 1000, 1000, 1000],
#               mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                      True,  True,  True,  True,  True,  True,  True,  True,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 0.1, 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 0.3, 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 0.5, 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 0.7, 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 0.9, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.3, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.5, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.7, 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 0.9, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.3, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.5, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.7, 'kernel': 'rbf'},
#   {'C': 100, 'gamma': 0.9, 'kernel': 'rbf'},
#   {'C': 500, 'gamma': 0.1, 'kernel': 'rbf'},
#   {'C': 500, 'gamma': 0.3, 'kernel': 'rbf'},
#   {'C': 500, 'gamma': 0.5, 'kernel': 'rbf'},
#   {'C': 500, 'gamma': 0.7, 'kernel': 'rbf'},
#   {'C': 500, 'gamma': 0.9, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 100, 'kernel': 'linear'},
#   {'C': 1000, 'kernel': 'linear'},
#   {'degree': 2, 'gamma': 0.01, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 2, 'gamma': 0.03, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 2, 'gamma': 0.05, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 3, 'gamma': 0.01, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 3, 'gamma': 0.03, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 3, 'gamma': 0.05, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 4, 'gamma': 0.01, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 4, 'gamma': 0.03, 'kernel': 'poly', 'max_iter': 1000},
#   {'degree': 4, 'gamma': 0.05, 'kernel': 'poly', 'max_iter': 1000}],
#  'split0_test_score': array([0.90760507, 0.90710474, 0.90710474, 0.90710474, 0.90710474,
#         0.90760507, 0.90677118, 0.90710474, 0.90710474, 0.90710474,
#         0.90760507, 0.90677118, 0.90710474, 0.90710474, 0.90710474,
#         0.90760507, 0.90677118, 0.90710474, 0.90710474, 0.90710474,
#         0.97948632, 0.9796531 , 0.97865243, 0.97898599, 0.42895264,
#         0.48999333, 0.17011341, 0.37158105, 0.1649433 , 0.15410274,
#         0.18228819, 0.16611074, 0.11574383]),
#  'split1_test_score': array([0.90792327, 0.90725605, 0.90725605, 0.90725605, 0.90725605,
#         0.90725605, 0.90642202, 0.90725605, 0.90725605, 0.90725605,
#         0.90725605, 0.90642202, 0.90725605, 0.90725605, 0.90725605,
#         0.90725605, 0.90642202, 0.90725605, 0.90725605, 0.90725605,
#         0.97964971, 0.98031693, 0.97864887, 0.97831526, 0.18065054,
#         0.22001668, 0.3206005 , 0.72176814, 0.15679733, 0.25788157,
#         0.89491243, 0.16880734, 0.89474562]),
#  'mean_test_score': array([0.90776417, 0.90718039, 0.90718039, 0.90718039, 0.90718039,
#         0.90743056, 0.9065966 , 0.90718039, 0.90718039, 0.90718039,
#         0.90743056, 0.9065966 , 0.90718039, 0.90718039, 0.90718039,
#         0.90743056, 0.9065966 , 0.90718039, 0.90718039, 0.90718039,
#         0.97956802, 0.97998502, 0.97865065, 0.97865063, 0.30480159,
#         0.355005  , 0.24535695, 0.5466746 , 0.16087031, 0.20599215,
#         0.53860031, 0.16745904, 0.50524473]),
#  'std_test_score': array([1.59099672e-04, 7.56551073e-05, 7.56551073e-05, 7.56551073e-05,
#         7.56551073e-05, 1.74511671e-04, 1.74581219e-04, 7.56551073e-05,
#         7.56551073e-05, 7.56551073e-05, 1.74511671e-04, 1.74581219e-04,
#         7.56551073e-05, 7.56551073e-05, 7.56551073e-05, 1.74511671e-04,
#         1.74581219e-04, 7.56551073e-05, 7.56551073e-05, 7.56551073e-05,
#         8.16919370e-05, 3.31914354e-04, 1.78044746e-06, 3.35363971e-04,
#         1.24151046e-01, 1.34988324e-01, 7.52435457e-02, 1.75093543e-01,
#         4.07298221e-03, 5.18894164e-02, 3.56312117e-01, 1.34829948e-03,
#         3.89500896e-01]),
#  'rank_test_score': array([ 5,  9,  9,  9,  9,  6, 22,  9,  9,  9,  6, 22,  9,  9,  9,  6, 22,
#          9,  9,  9,  2,  1,  3,  4, 29, 28, 30, 25, 33, 31, 26, 32, 27])}

# %%
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %% [markdown]
# ### d)

# %%
clf = SVC(kernel='linear', C=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.97866937531742

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[5355,   26],
#        [ 100,  426]], dtype=int64)

# %%
clf = SVC(kernel='linear', C=10)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.9781615033011681

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[5352,   29],
#        [ 100,  426]], dtype=int64)
